# %%
from anthropic import Anthropic
import os
client = Anthropic(api_key=os.getenv('ANTHROPIC_API_KEY'))

def add_user_message(messages, text):
    user_message = {"role": "user" , "message": f"{text}"}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant" , "message": f"{text}"}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model='claude-sonnet-4-5',
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Define quantum computing in one sentence")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "Write another sentence")

# Get the follow-up response with full context
final_answer = chat(messages)

# %%
# %pip install google-generativeai

# %%
from google import genai
from google.genai import types
import os

client = genai.Client(api_key=os.getenv('GEMINI_API_KEY'))
model =  "gemini-2.5-flash-lite"
max_token = 1000


def add_user_message(messages, text):
    messages.append({
        "role": "user",
        "parts": [{"text": text}]
    })

def add_assistant_message(messages, text):
    messages.append({
        "role": "model",
        "parts": [{"text": text}]
    })


def chat(messages):
    config = {
        "max_output_tokens": 10000
    }
    response = client.models.generate_content(
        model = model,
        contents = messages,
        config = types.GenerateContentConfig(**config)
    )
    return response.text

# %%
messages = []

add_user_message(messages, "Explain PCA in simple words")

reply = chat(messages)
print(reply)

# print(reply)

# add_assistant_message(messages, reply)

# reply = chat(messages)

# print(reply)
# Out:
# Imagine you have a big pile of information, like a giant spreadsheet with tons of columns (features) describing something. This information can be overwhelming and sometimes redundant. **Principal Component Analysis (PCA)** is a way to **simplify this information** without losing too much of its essence.
#
# Think of it like this:
#
# **The Problem:**
#
# *   You have many different ways to describe something (e.g., describing a car with its horsepower, engine size, number of doors, fuel efficiency, price, color, etc.).
# *   Some of these descriptions might be very similar (e.g., horsepower and engine size are often related).
# *   Having too many descriptions can make it hard to see the important patterns or to work with the data efficiently.
#
# **The Solution (PCA):**
#
# PCA finds **new, more important ways to describe your data** that are combinations of the old descriptions. These new ways are called **Principal Components**.
#
# Here's a simple analogy:
#
# **Analogy: Describing a Person's Height**
#
# Imagine you want to describe a person. You could measure:
#
# *   Height from the top of their head to their feet.
# *   Height from their chin to their feet.
# *   Height from their shoulders to their feet.
#
# Notice how these are all very similar and tell you essentially the same thing: how tall they are.
#
# PCA would say, "Instead of all these slightly different ways of measuring height, let's just create one **'Overall Height'** component." This one component captures most of the variation in those initial measurements.
#
# **How PCA Works (Simplified):**
#
# 1.  **Finding Directions of Maximum Variation:** PCA looks at your data and figures out which directions have the most "spread" or "variance." Think of it like looking at a scatter plot of your data points and finding the line that best captures the overall trend.
#
# 2.  **Creating New "Super-Variables" (Principal Components):** It then creates new "variables" (Principal Components) that are combinations of your original variables. The **first Principal Component** captures the **most** variance (the most important pattern) in your data. The **second Principal Component** captures the **next most** variance, and it's **independent** (not related) to the first one. This continues for subsequent components.
#
# 3.  **Reducing the Number of Variables:** The goal is to use just a few of these Principal Components to represent most of the important information in your original, large set of variables. So, instead of 100 original columns, you might only need 5 Principal Components.
#
# **Why is this useful?**
#
# *   **Simplification:** Makes your data easier to understand and visualize.
# *   **Noise Reduction:** Can help remove less important variations (noise) in the data, making the important signals clearer.
# *   **Efficiency:** Reduces the number of features you need to work with, making your computer models faster and more efficient.
# *   **Dimensionality Reduction:** This is the technical term for reducing the number of variables.
#
# **In a nutshell:**
#
# PCA takes a complex dataset with many features and transforms it into a simpler dataset with fewer features (called Principal Components) while preserving as much of the original information as possible. It's like finding the most important underlying themes in your data.

# %%
from google import genai
from google.genai import types
import os

client = genai.client(api_key=os.getenv('GEMINI_API_KEY'))
model = "gemini-2.5-flash-lite"

def add_user_message(messages, text):
    messages.append({
        "role": "user",
        "parts": [{"text": text}]
    })

def add_assistant_message(messages, text):
    messages.append({
        "role": "model",
        "parts": [{"text": text}]
    })


def chat(messages, system_prompt= None , temperature = 1.0):
    config = {
        "max_output_tokens": 10000,
        "temperature": temperature
    }
    if system_prompt:
        config["system_instruction"] = system_prompt
    response = client.models.generate_content(
        model,
        messages,
        generation_config=types.GenerateContentConfig(**config)
    )

    return response.text
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       2 from google.genai import types
#       3 import os
# ----> 5 client = genai.client(api_key=os.getenv('GEMINI_API_KEY'))
#       6 model = "gemini-2.5-flash-lite"
#       8 def add_user_message(messages, text):
#
# TypeError: 'module' object is not callable

# %%
#system prompt exercise 

messages=[]

add_user_message(messages, "write python function that check a string  for duplicate charaters.")

reply=chat(messages, system_prompt="you are a python engineer who write a concise code" )

print(reply)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 7
#       3 messages=[]
#       5 add_user_message(messages, "write python function that check a string  for duplicate charaters.")
# ----> 7 reply=chat(messages, system_prompt="you are a python engineer who write a concise code" )
#       9 print(reply)
#
# Cell In[28], line 26, in chat(messages, system_prompt, temperature)
#      24 if system_prompt:
#      25     config["system_instruction"] = system_prompt
# ---> 26 response = model.generate_content(
#      27     messages,
#      28     generation_config=types.GenerateContentConfig(**config)
#      29 )
#      31 return response.text
#
# File c:\Users\ayush\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\generativeai\generative_models.py:305, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     302 if not contents:
#     303     raise TypeError("contents must not be empty")
# --> 305 request = self._prepare_request(
#     306     contents=contents,
#     307     generation_config=generation_config,
#     308     safety_settings=safety_settings,
#     309     tools=tools,
#     310     tool_config=tool_config,
#     311 )
#     313 if request.contents and not request.contents[-1].role:
#     314     request.contents[-1].role = _USER_ROLE
#
# File c:\Users\ayush\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\generativeai\generative_models.py:156, in GenerativeModel._prepare_request(self, contents, generation_config, safety_settings, tools, tool_config)
#     152     tool_config = content_types.to_tool_config(tool_config)
#     154 contents = content_types.to_contents(contents)
# --> 156 generation_config = generation_types.to_generation_config_dict(generation_config)
#     157 merged_gc = self._generation_config.copy()
#     158 merged_gc.update(generation_config)
#
# File c:\Users\ayush\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\generativeai\types\generation_types.py:224, in to_generation_config_dict(generation_config)
#     222     return generation_config
#     223 else:
# --> 224     raise TypeError(
#     225         "Invalid input type. Expected a `dict` or `GenerationConfig` for `generation_config`.\n"
#     226         f"However, received an object of type: {type(generation_config)}.\n"
#     227         f"Object Value: {generation_config}"
#     228     )
#
# TypeError: Invalid input type. Expected a `dict` or `GenerationConfig` for `generation_config`.
# However, received an object of type: <class 'google.genai.types.GenerateContentConfig'>.
# Object Value: http_options=None should_return_http_response=None system_instruction='you are a python engineer who write a concise code' temperature=1.0 top_p=None top_k=None candidate_count=None max_output_tokens=10000 stop_sequences=None response_logprobs=None logprobs=None presence_penalty=None frequency_penalty=None seed=None response_mime_type=None response_schema=None response_json_schema=None routing_config=None model_selection_config=None safety_settings=None tools=None tool_config=None labels=None cached_content=None response_modalities=None media_resolution=None speech_config=None audio_timestamp=None automatic_function_calling=None thinking_config=None image_config=None enable_enhanced_civic_answers=None model_armor_config=None

# %%
messages = []

add_user_message(messages, "Explain PCA in simple words")

reply = chat(messages)

print(reply)

print("response from 1 message")

add_assistant_message(messages, reply)

add_user_message(messages , "explain with example")

reply = chat(messages)

print(reply)

print("response from 2 message")
# Out:
# Imagine you have a huge spreadsheet with hundreds of columns (features) about something – say, characteristics of thousands of different fruits. Trying to understand all of them at once is like trying to see all sides of a complex object simultaneously – it's overwhelming.
#
# **PCA's job is to simplify this.**
#
# Think of it like this:
#
# 1.  **The Overwhelm:** You have a 3D object (like a banana). You can look at it from the front, side, top, diagonal, etc. If you just take random photos, you might have many that look similar or don't show the most important aspects.
#
# 2.  **Finding the "Best Angles":** PCA finds the "best angles" or "directions" to look at your data that capture the most information and show the most differences between the data points.
#
#     *   The **first "best angle"** (called the **First Principal Component**) is the one that shows the *most spread* or *most variation* in your data. If you take a photo from this angle, you'd see the most important distinguishing features of your fruit.
#     *   The **second "best angle"** (the **Second Principal Component**) is another direction that captures the *next most variation*, but it's completely independent of the first (like looking at the object from a perfect 90-degree turn from the first angle).
#     *   And so on. Each subsequent "angle" captures less and less new information.
#
# 3.  **Simplifying and Summarizing:** Instead of looking at hundreds of original columns, you can often look at just the first few "best angles" (Principal Components) and still understand most of what's going on in your data. You've essentially **summarized your data** from many dimensions down to just a few, without losing too much of the important stuff.
#
# **In simple words:**
#
# PCA helps you **find the main patterns** and **reduce the complexity** of your data by identifying the most important "directions" or "dimensions" where your data varies the most. It's like distilling a long, detailed story down to its most crucial plot points.
# response from 1 message
# Okay, let's use an example of **houses** to make it clearer.
#
# Imagine you're a real estate agent trying to understand and categorize thousands of houses. For each house, you have a lot of information (features):
#
# *   **Square Footage**
# *   **Number of Bedrooms**
# *   **Number of Bathrooms**
# *   **Lot Size (in acres)**
# *   **Year Built**
# *   **Number of Floors**
# *   **Distance to Nearest Park**
# *   **School District Rating**
# *   And many more...
#
# That's like having 20-30 different columns for each house! It's hard to get a quick overview or compare houses efficiently.
#
# **Here's how PCA helps:**
#
# 1.  **The Overwhelm:** You have all these numbers for each house. You notice that `Square Footage`, `Number of Bedrooms`, and `Number of Bathrooms` often go up or down together. A bigger house usually has more bedrooms and bathrooms. These features are *correlated*.
#
# 2.  **PCA as a "Smart Blender":**
#     PCA looks at all these features and says, "Hey, many of these features are actually telling me similar things. Let's create new, smarter 'summary features' that capture the most important information."
#
#     *   **First Principal Component (PC1): The "Overall Size/Luxury Score"**
#         PCA looks at your data and finds the *single most important combination* of features that explains the most variation among houses. It might find that a blend of `Square Footage`, `Number of Bedrooms`, and `Number of Bathrooms` is incredibly powerful.
#         *   Houses with high `Square Footage`, many `Bedrooms`, and many `Bathrooms` will score high on this PC1.
#         *   Small houses with few bedrooms/bathrooms will score low.
#         *   Essentially, PC1 becomes your single "Overall Size/Luxury Score" for each house. This one score now tells you *most* of what those three original columns were telling you, but in a much simpler form.
#
#     *   **Second Principal Component (PC2): The "Suburban vs. Urban/Land Abundance Score"**
#         Next, PCA finds the *next most important combination* of features that explains the remaining variation, but it has to be *independent* of the first score. This might be a blend of `Lot Size` and `Distance to Nearest Park`.
#         *   A house with a large `Lot Size` and far from a park (often implies more land/suburban) might score high on this PC2.
#         *   A house with a small `Lot Size` near a city park might score low.
#         *   This PC2 tells you something about the house's setting, distinct from its internal size.
#
# 3.  **The Benefit – Simplification and Focus:**
#
#     Instead of looking at 20-30 separate columns, you might find that just the first 2 or 3 Principal Components (like our "Overall Size/Luxury Score" and "Suburban vs. Urban Score") capture 80-90% of all the important information about the houses.
#
#     *   You've gone from a complex 20-30 dimensional view down to just 2-3 dimensions.
#     *   This makes it much easier to:
#         *   **Understand:** Quickly grasp the main differences between houses.
#         *   **Visualize:** You could plot houses on a simple graph with PC1 on one axis and PC2 on the other, and see clusters of similar houses (e.g., luxury suburban, small urban, mid-range family homes).
#         *   **Build models:** If you were using this data for prediction, using 2-3 strong Principal Components instead of 20-30 original features can make your models faster and more robust.
#
# So, in the house example, PCA helps you cut through the noise of many individual features and boils down the essence of what makes houses different into a few powerful, composite scores.
# response from 2 message

# %%
#chat exercise
iscontinue_chat= True
# prompt = input("enter prompt")
# if prompt.toLower() == "stop":
#     iscontinue_chat = False
messages = []
while(iscontinue_chat):
    prompt = input("Enter prompt")
    print("user input >", prompt )
    if prompt =="stop":
        iscontinue_chat= False
        break
    add_user_message(messages, prompt)
    reply = chat(messages)
    add_assistant_message(messages , reply)


    print("----------------------")
    print(reply)
    print("----------------------")
# Out:
# user input > 2+2
# ----------------------
# 4
# ----------------------
# user input > 2 more
# ----------------------
# 6
# ----------------------
# user input > 2 more
# ----------------------
# 8
# ----------------------
# user input > stop

# %%
# system prompt provide guidence on how to response to question ask (in anthropic we pass system prompt as parameter to creat
# function but in gemini we have system_instruction as parmeter)
system_prompt = ''' You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.'''

def chat(messages):
    response = model.generate_content(
        messages,
        generation_config={
            "max_output_tokens": 10000
        }
    )

# %%
system_prompt = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""

model = genai.GenerativeModel(
    "gemini-1.5-flash",
    system_instruction=system_prompt
)

response = model.generate_content("What is 2 + 2?")
print(response.text)
