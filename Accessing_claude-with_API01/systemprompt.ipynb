# %%
#inports 
from anthropic import Anthropic
import os

# %%
client = Anthropic(api_key=os.getenv('ANTHROPIC_API_KEY'))
model = 'claude-sonnet-4-5'

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None , temperature = 1.0 , stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences" : stop_sequences
    }
    
    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
    return message.content[0].text

# %%
## system prompot
messages =[]
add_user_message(messages , "how do i solve this 5x+3 = 2 fox x ?")
system_prompt = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""
answer = chat(messages , system_prompt)
print(answer)
# Out:
# I'll help you solve for x step by step!
#
# You have: 5x + 3 = 2
#
# **First question for you:** What do you think should be our first step to get x by itself on one side of the equation?
#
# *Hint: Think about what's "attached" to the x term. What operation is connecting the 3 to the 5x?*

# %%
#system prompt exercise
messages=[]

add_user_message(messages, "write a python function that checks a string for duplicate charaters")
system_prompt = """
    you are a python engineer who write code very concise code    
"""
answer = chat(messages, system_prompt)

print(answer)
# Out:
# Here's a concise Python function to check for duplicate characters:
#
# ```python
# def has_duplicates(s: str) -> bool:
#     return len(s) != len(set(s))
# ```
#
# **Usage:**
# ```python
# print(has_duplicates("hello"))    # True (l appears twice)
# print(has_duplicates("world"))    # False
# print(has_duplicates("python"))   # False
# print(has_duplicates("aardvark")) # True
# ```
#
# **How it works:**
# - Converts string to a set (removes duplicates)
# - Compares original length with set length
# - If lengths differ, duplicates exist
#
# **Alternative (returns duplicate characters):**
# ```python
# def find_duplicates(s: str) -> set:
#     return {char for char in s if s.count(char) > 1}
# ```
#
# ```python
# print(find_duplicates("hello"))    # {'l'}
# print(find_duplicates("aardvark")) # {'a'}
# ```

# %%
#temprature learning
messages=[]

add_user_message(messages, "generate a one sentence movie idea")

answer =chat(messages, temperature=1.0)
answer
# Out:
# 'A lonely astronaut discovers their AI companion has been hiding the fact that Earth was destroyed years ago, and they must decide whether to live in blissful ignorance or face devastating truth.'

# %%
messages = []
add_user_message(messages, "write a one sentence description of a fake database")

# stream = client.messages.create(
#     model= model, 
#     max_token = 1000,
#     messages=messages,
#     stream= True
# )
with client.messages.stream(
    model = model,
    max_tokens= 1000,
    messages= messages
) as  stream:
    for event in stream.text_stream:
        print(event , end="")
stream.get_final_message()
# Out:
# A fictional database called "PetersonCorp Customer Records" containing 50,000 entries with fields for customer ID, name, email, purchase history, and account status from 2019-2024.
# ParsedMessage(id='msg_01UtbYQMithD8yF1crEFxdkP', container=None, content=[ParsedTextBlock(citations=None, text='A fictional database called "PetersonCorp Customer Records" containing 50,000 entries with fields for customer ID, name, email, purchase history, and account status from 2019-2024.', type='text', parsed_output=None)], model='claude-sonnet-4-5-20250929', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=16, output_tokens=47, server_tool_use=None, service_tier='standard'))

# %%
#prefilling 
messages = []
add_user_message(messages, "Is tea or coffee better at breakfast?")
add_assistant_message(messages, "Coffee is better because")
answer = chat(messages)
answer
# Out:
# " it has more caffeine and delivers a quicker energy boost to help you wake up. Many people find this particularly helpful in the morning.\n\nThat said, tea can be a great choice if you:\n- Prefer a gentler caffeine lift\n- Want something easier on your stomach\n- Enjoy the ritual of brewing loose leaf varieties\n- Are sensitive to coffee's acidity\n\nIt really depends on your personal preferences, caffeine tolerance, and how your body responds to each. What matters most is which one makes your morning feel better to you."

# %%
#stop sequence
messages = []
add_user_message(messages, "Count from 1 to 10")
answer = chat(messages, stop_sequences=["5"])
print(answer)
# Out:
# 1, 2, 3, 4,

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------

# %%
from google import genai
from google.genai import types
import os
client = genai.Client(api_key='AIzaSyA_-V4vSuyk8JKZoC0WFATKiL6mOqSSSjU')

system_prompt = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them step by step.
"""

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="How do I solve 2x + 4 = 10?",
    config=types.GenerateContentConfig(
        system_instruction=system_prompt
    )
)

print(response.text)
# Out:
# That's a great question! We want to find the value of 'x' that makes this equation true.
#
# Think about it like a balanced scale. Whatever you do to one side, you must do to the other to keep it balanced.
#
# Our equation is $2x + 4 = 10$.
#
# What's the first thing we could do to start isolating the 'x' term?

# %%
chat = model.start_chat(history=[])

response = chat.send_message("How do I solve 2x + 4 = 10?")
print(response.text)

# %%
from google import genai
from google.genai import types
import os

client = genai.Client(api_key='AIzaSyA_-V4vSuyk8JKZoC0WFATKiL6mOqSSSjU')
model = "gemini-2.5-flash-lite"
def add_user_message(messages, text):
    messages.append({
        "role": "user",
        "parts": [{"text": text}]
    })

def add_assistant_message(messages, text):
    messages.append({
        "role": "model",
        "parts": [{"text": text}]
    })

# def chat(messages, system_prompt=None , temperature = 1.0):
#     response = client.models.generate_content(
#         model= model,
#         contents=messages,
#         config=types.GenerateContentConfig(
#             system_instruction=system_prompt,
#             max_output_tokens=10000,
#             temperature= temperature,
            
#         )
#     )
#     return response.text


def chat(messages, system_prompt=None, temperature=1.0):

    config = {
        "max_output_tokens": 1000,
        "temperature": temperature
    }

    if system_prompt:
        config["system_instruction"] = system_prompt

    response = client.models.generate_content(
        model=model,
        contents=messages,
        config=types.GenerateContentConfig(**config)
    )

    return response.text

# %%
messages = []

add_user_message(messages,
    "write python function that check a string for duplicate characters"
)

reply = chat(
    messages,
    system_prompt="you are a python engineer who writes concise code"
)

print(reply)
# Out:
# ```python
# def has_duplicates(s: str) -> bool:
#     """
#     Checks a string for duplicate characters.
#
#     Args:
#         s: The input string.
#
#     Returns:
#         True if the string contains duplicate characters, False otherwise.
#     """
#     return len(set(s)) != len(s)
# ```

# %%
# temprature value lies between 0.0 to 1.0 the value of temprature increase the content 
# creativity will be increase and descres ai model will generate deterninastic ans
# Low Temperature (0.0 - 0.3)
# Medium Temperature (0.4 - 0.7)
# High Temperature (0.8 - 1.0)

messages = []

add_user_message(messages,
    "Generate one sentence movie idea"
)

reply = chat(
    messages,
    temperature= 1.0
    # system_prompt="you are a python engineer who writes concise code"
)

print(reply)
# Out:
# A grieving architect discovers his late wife secretly built a portal to an alternate dimension, where she is still alive but doesn't recognize him, forcing him to choose between his reality and hers.*

# %%
# streaming enabled 

from google import genai
from google.genai import types
import os

client = genai.Client(api_key='AIzaSyA_-V4vSuyk8JKZoC0WFATKiL6mOqSSSjU')

def add_user_message(messages, text):
    messages.append({
        "role": "user",
        "parts": [{"text": text}]
    })

def add_assistant_message(messages, text):
    messages.append({
        "role": "model",
        "parts": [{"text": text}]
    })

def chatwithstreamfunction(messages, system_prompt=None, temperature=1.0 , stop_sequences=[]):
    
    config = {
        "max_output_tokens": 100000,
        "temperature": temperature,
        "stop_sequences" : stop_sequences
    }

    if system_prompt:
        config["system_instruction"] = system_prompt

   
    stream = client.models.generate_content_stream(
        model=model,
        contents=messages,
        config=types.GenerateContentConfig(**config)
    )
    full_text = ""
    for chunk in stream:
        if chunk.text:
            # Send chunk to client (like Claude text_stream)
            print(chunk.text, end="", flush=True)
            full_text += chunk.text

    # Equivalent of get_final_message()
    return full_text 

def chatwithgeneratefunction(messages , system_prompt=None, temperature=1.0 , stop_sequences=[]):
    config = {
        "max_output_tokens": 100000,
        "temperature": temperature,
        "stop_sequences" : stop_sequences
    }

    if system_prompt:
        config["system_instruction"] = system_prompt
    
    response = client.models.generate_content(
        model=model,
        contents=messages,
        config=types.GenerateContentConfig(**config)
    )
    return response.text[0]

# %%
messages = []

add_user_message(messages, 
    "write ten line essay on school in hindi language "
)

reply = chatwithstreamfunction(
    messages,
    # system_prompt="you are a python engineer who writes concise code"
)
# Out:
# Here is a ten-line essay on school in Hindi:
#
# विद्यालय ज्ञान का मंदिर है। यह वह स्थान है जहाँ बच्चे शिक्षा प्राप्त करते हैं। यहाँ शिक्षक बच्चों को अच्छी आदतें और संस्कार सिखाते हैं। विद्यालय में हम नई चीजें सीखते हैं और अपने भविष्य की नींव रखते हैं। यह अनुशासन और सहयोग का पाठ भी सिखाता है। मित्र बनाते हैं और मिलकर खेलते-पढ़ते हैं। विद्यालय हमें एक अच्छा नागरिक बनने में मदद करता है। यहाँ हमें विभिन्न विषयों का ज्ञान मिलता है। विद्यालय जीवन का एक महत्वपूर्ण अंग है। यह हमारे उज्वल भविष्य का मार्ग प्रशस्त करता है।

# %%
# controlling model output use prefilled assistant messages 
''''instead of just sending a user message, you add an assistant message at the end of your message list. 
    Claude sees this assistant message and thinks 
"I've already started responding to this question, so I should continue from where I left off."'''
messages = []

add_user_message(messages, 
    "is tea or coffee which is better in brakefast"
)
add_assistant_message(messages , "coffee is better")
reply = chatwithstreamfunction(
    messages,
    # system_prompt="you are a python engineer who writes concise code"
)
# Out:
#  for breakfast because it has more caffeine which can help you wake up and be more productive

# %%
#Stop Sequences
# Stop sequences force Claude to end its response immediately when it generates a specific string of characters.
#  This is perfect for controlling the length or endpoint of responses.
# force gemini to end the response as soon as  it generate string  matching your  stop sequence

# %%
# exmaple i ask ai to print 1 to 10 no and in assistent message i have given 1 to 3 and stop sequence i have given 5 as stop then ai will stop at 5
messages=[]
add_user_message(messages , "count 1 to 10")
# add_assistant_message(messages ,"")
reply = chatwithstreamfunction(messages, stop_sequences=["5"])
# print(reply)
# Out:
# 1, 2, 3, 4,
