# %%
# STEP -1 install dependencies
# %pip install anthropic python-dotenv

# %%
# STEP -2 CREATE ENV FILE AND APP API KEY and load API 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
#Step create an API client 
from anthropic import Anthropic
import os
# api_key = os.getenv("ANTHROPIC_API_KEY")
# print(api_key)
client = Anthropic(api_key=os.getenv('ANTHROPIC_API_KEY'))
model = "claude-sonnet-4-0"

# %%
# Make a request
message= client.messages.create(
    model = model,
    max_tokens= 1000,
    messages=[
        {
            "role": "user",
            "content": "what is quantum computing? Answer in one sentence"
        }
    ]
)
print(message.content[0].text)
# Out:
# Quantum computing is a revolutionary computing paradigm that uses quantum mechanical phenomena like superposition and entanglement to process information in ways that can potentially solve certain problems exponentially faster than classical computers.

# %%
# lets test gemini api 
 # install required dependencies
# %pip install google-genai

# %%
import types

from google import genai
from google.genai import types  # this is where 'types' comes from
# gemini-2.0-flash       Fast, efficient (recommended)
# gemini-2.5-pro         Most capable
# gemini-2.0-flash-lite  Cheapest/fastest
client = genai.Client(api_key='GEMINI_API_KEY')

# response = client.models.generate_content(
#     model="gemini-2.5-flash",
#     contents="what is quantum computing? Answer in one sentence"
# )
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[types.Part.from_text(text="Explain what is quantum computing with example")],
    config=types.GenerateContentConfig(
    max_output_tokens=1000,
    temperature=0.7,       # creativity (0 = deterministic, 1 = creative)
    top_p=0.9,
    )
)
print(response.text)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[types.Part.from_text(text="write another sentence")],
    config=types.GenerateContentConfig(
    max_output_tokens=1000,
    temperature=0.7,       # creativity (0 = deterministic, 1 = creative)
    top_p=0.9,
    )
)
# response = client.models.generate_content(
#     model="gemini-2.0-flash",
#     contents=[
#              types.Part.from_text(text='What is shown in this image?'),

#     ],
#     config=types.GenerateContentConfig(
#         max_output_tokens=1000,
#     )
# )
print(response.text)
# Out:
# Quantum computing is a **revolutionary type of computation that harnesses the principles of quantum mechanics** to solve complex problems that are intractable for even the most powerful classical computers.
#
# Instead of relying on classical bits
# The rain began to fall softly outside.

# %%
# in anthropic do not have memory to store context of chat means when I will ask what is quantum computing then 
# it will give me some other response but in next message i will ask write another sentance then it will give me
# totally other response means it do not have context.
